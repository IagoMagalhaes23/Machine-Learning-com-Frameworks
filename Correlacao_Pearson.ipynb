# %% [markdown]
# <a href="https://colab.research.google.com/github/IagoMagalhaes23/Machine-Learning-com-Frameworks/blob/main/Correlacao_Pearson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Library import
import pandas as pd
import seaborn as sn
from google.colab import files

uploaded = files.upload()
for fn in uploaded.keys():
  print('Arquivo carregado com sucesso! \n "{name}" com tamanho de {length} bytes'.format(name=fn, length=len(uploaded[fn])))


#Leitura dos dados
data = pd.read_csv("temp1em1.csv")

print(data)

#Análise de correlação
correlation = data.corr()

#Plot da matriz de correlação
plot = sn.heatmap(correlation, annot = True, fmt=".1f", linewidths=.6)
plot
# Out:
#      <input type="file" id="files-aa115733-35d6-45f8-8cb0-262e8f5a4a27" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-aa115733-35d6-45f8-8cb0-262e8f5a4a27">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving temp1em1.csv to temp1em1.csv
# Arquivo carregado com sucesso!
#  "temp1em1.csv" com tamanho de 130465 bytes
#       Unnamed: 0  temperatura1  temperatura2  ...  temperatura6        data   hora
# 0              0     264.08790     301.61365  ...     159.61319  20/09/2021  22:35
# 1              1     257.32430     300.54932  ...     159.26985  20/09/2021  17:58
# 2              2     257.70200     300.61798  ...     159.47585  20/09/2021  17:59
# 3              3     257.97665     300.82397  ...     159.61319  20/09/2021  18:00
# 4              4     258.07965     301.44196  ...     159.37285  20/09/2021  18:01
# ...          ...           ...           ...  ...           ...         ...    ...
# 1435        1435     264.84323     301.47632  ...     159.68185  21/09/2021  17:55
# 1436        1436     264.67157     301.30463  ...     159.68185  21/09/2021  17:56
# 1437        1437     264.63724     301.02997  ...     159.37285  21/09/2021  17:57
# 1438        1438     264.29388     301.54498  ...     159.71619  21/09/2021  20:14
# 1439        1439     265.01490     300.78964  ...     159.54453  22/09/2021  13:12
#
# [1440 rows x 9 columns]
